# %% [markdown]
# # ADS ASSIGNMENT- AMOGH A M

# %% [markdown]
# ## Load the Dataset

# %%
import pandas as pd

# %%
df=pd.read_csv("titanic.csv")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# ##  Perform Below Visualizations.

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### HISTOGRAM

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['pclass'],color='purple')
# Out:
# (array([216.,   0.,   0.,   0.,   0., 184.,   0.,   0.,   0., 491.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #### PIE CHART

# %%
categories = list(df['embarked'].unique())
value_counts = df['embarked'].value_counts()

# %%
plt.pie(value_counts,labels=categories[:-1])
# Out:
# ([<matplotlib.patches.Wedge at 0x26734bb20d0>,
#   <matplotlib.patches.Wedge at 0x26734bb25b0>,
#   <matplotlib.patches.Wedge at 0x26734bb2ac0>],
#  [Text(-0.7128398214280038, 0.8377704870586524, 'S'),
#   Text(0.4614522559226597, -0.9985298270476893, 'C'),
#   Text(1.0595276168013974, -0.29563698894954155, 'Q')])

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### BOX PLOT

# %%
import seaborn as sns
sns.boxplot(x='pclass', y='fare', data=df)
plt.title('Fare by Passenger Class')
plt.show()

# %% [markdown]
# #### STACKED BAR CAHRT

# %%
survival_counts = df.groupby('pclass')['survived'].value_counts().unstack()
colors = ['tab:blue', 'tab:green']
survival_counts.plot(kind='bar', stacked=True,color=colors)
plt.xlabel('Passenger Class')
plt.ylabel('Survival Count')
plt.title('Survival Count by Passenger Class')
plt.show()

# %% [markdown]
# ### Multivariate Analysis

# %% [markdown]
# #### SCATTER PLOT

# %%
sns.scatterplot(x='age', y='fare', hue='pclass', data=df)
plt.title('Age vs. Fare (colored by pclass)')
plt.show()

# %% [markdown]
# #### CAT PLOT

# %%
sns.catplot(x='pclass', hue='sex', col='survived', data=df, kind='count')
plt.suptitle('Survival by Passenger Class and Gender')
plt.show()

# %% [markdown]
# ### Perform Descriptive Statistics on dataset

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### Handle the Missing Values

# %%
df['deck'].fillna("None", inplace=True)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  deck  embark_town alive  alone
# 0      man        True  None  Southampton    no  False
# 1    woman       False     C    Cherbourg   yes  False
# 2    woman       False  None  Southampton   yes   True
# 3    woman       False     C  Southampton   yes  False
# 4      man        True  None  Southampton    no   True
# ..     ...         ...   ...          ...   ...    ...
# 886    man        True  None  Southampton    no   True
# 887  woman       False     B  Southampton   yes   True
# 888  woman       False  None  Southampton    no  False
# 889    man        True     C    Cherbourg   yes   True
# 890    man        True  None   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df['age'].fillna(df['age'].mean(), inplace=True)

# %%
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male  deck  embark_town alive  alone
# 0     Third    man        True  None  Southampton    no  False
# 1     First  woman       False     C    Cherbourg   yes  False
# 2     Third  woman       False  None  Southampton   yes   True
# 3     First  woman       False     C  Southampton   yes  False
# 4     Third    man        True  None  Southampton    no   True
# ..      ...    ...         ...   ...          ...   ...    ...
# 886  Second    man        True  None  Southampton    no   True
# 887   First  woman       False     B  Southampton   yes   True
# 888   Third  woman       False  None  Southampton    no  False
# 889   First    man        True     C    Cherbourg   yes   True
# 890   Third    man        True  None   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# ###  Find the outliers and replace the outliers

# %%
import numpy as np
z_threshold = 3
z_scores = (df['age'] - df['age'].mean()) / df['age'].std()
outliers = (np.abs(z_scores) > z_threshold)
df.loc[outliers,'age'] = df['age'].mean()

# %%
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class    who  adult_male  deck  embark_town alive  alone
# 0     Third    man        True  None  Southampton    no  False
# 1     First  woman       False     C    Cherbourg   yes  False
# 2     Third  woman       False  None  Southampton   yes   True
# 3     First  woman       False     C  Southampton   yes  False
# 4     Third    man        True  None  Southampton    no   True
# ..      ...    ...         ...   ...          ...   ...    ...
# 886  Second    man        True  None  Southampton    no   True
# 887   First  woman       False     B  Southampton   yes   True
# 888   Third  woman       False  None  Southampton    no  False
# 889   First    man        True     C    Cherbourg   yes   True
# 890   Third    man        True  None   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# ### Check for Categorical columns and perform encoding.

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
df['who']= label_encoder.fit_transform(df['who'])

# %%
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class  who  adult_male  deck  embark_town alive  alone
# 0     Third    1        True  None  Southampton    no  False
# 1     First    2       False     C    Cherbourg   yes  False
# 2     Third    2       False  None  Southampton   yes   True
# 3     First    2       False     C  Southampton   yes  False
# 4     Third    1        True  None  Southampton    no   True
# ..      ...  ...         ...   ...          ...   ...    ...
# 886  Second    1        True  None  Southampton    no   True
# 887   First    2       False     B  Southampton   yes   True
# 888   Third    2       False  None  Southampton    no  False
# 889   First    1        True     C    Cherbourg   yes   True
# 890   Third    1        True  None   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# ### Split the data into dependent and independent variables.

# %%
x = df.drop(columns="survived")
y=df['survived']

# %%
#Independent variables
x
# Out:
#      pclass     sex        age  sibsp  parch     fare embarked   class  who  \
# 0         3    male  22.000000      1      0   7.2500        S   Third    1
# 1         1  female  38.000000      1      0  71.2833        C   First    2
# 2         3  female  26.000000      0      0   7.9250        S   Third    2
# 3         1  female  35.000000      1      0  53.1000        S   First    2
# 4         3    male  35.000000      0      0   8.0500        S   Third    1
# ..      ...     ...        ...    ...    ...      ...      ...     ...  ...
# 886       2    male  27.000000      0      0  13.0000        S  Second    1
# 887       1  female  19.000000      0      0  30.0000        S   First    2
# 888       3  female  29.699118      1      2  23.4500        S   Third    2
# 889       1    male  26.000000      0      0  30.0000        C   First    1
# 890       3    male  32.000000      0      0   7.7500        Q   Third    1
#
#      adult_male  deck  embark_town alive  alone
# 0          True  None  Southampton    no  False
# 1         False     C    Cherbourg   yes  False
# 2         False  None  Southampton   yes   True
# 3         False     C  Southampton   yes  False
# 4          True  None  Southampton    no   True
# ..          ...   ...          ...   ...    ...
# 886        True  None  Southampton    no   True
# 887       False     B  Southampton   yes   True
# 888       False  None  Southampton    no  False
# 889        True     C    Cherbourg   yes   True
# 890        True  None   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
#Dependent Variables
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %% [markdown]
# ### Scale the independent variables

# %%
min_value = df['fare'].min()
max_value = df['fare'].max()
df['scaled_fare']  = (df['fare'] - min_value) / (max_value - min_value)

# Assign the scaled column back to the dataset

# %%
df
# Out:
#      survived  pclass     sex        age  sibsp  parch     fare embarked  \
# 0           0       3    male  22.000000      1      0   7.2500        S
# 1           1       1  female  38.000000      1      0  71.2833        C
# 2           1       3  female  26.000000      0      0   7.9250        S
# 3           1       1  female  35.000000      1      0  53.1000        S
# 4           0       3    male  35.000000      0      0   8.0500        S
# ..        ...     ...     ...        ...    ...    ...      ...      ...
# 886         0       2    male  27.000000      0      0  13.0000        S
# 887         1       1  female  19.000000      0      0  30.0000        S
# 888         0       3  female  29.699118      1      2  23.4500        S
# 889         1       1    male  26.000000      0      0  30.0000        C
# 890         0       3    male  32.000000      0      0   7.7500        Q
#
#       class  who  adult_male  deck  embark_town alive  alone  scaled_fare
# 0     Third    1        True  None  Southampton    no  False     0.014151
# 1     First    2       False     C    Cherbourg   yes  False     0.139136
# 2     Third    2       False  None  Southampton   yes   True     0.015469
# 3     First    2       False     C  Southampton   yes  False     0.103644
# 4     Third    1        True  None  Southampton    no   True     0.015713
# ..      ...  ...         ...   ...          ...   ...    ...          ...
# 886  Second    1        True  None  Southampton    no   True     0.025374
# 887   First    2       False     B  Southampton   yes   True     0.058556
# 888   Third    2       False  None  Southampton    no  False     0.045771
# 889   First    1        True     C    Cherbourg   yes   True     0.058556
# 890   Third    1        True  None   Queenstown    no   True     0.015127
#
# [891 rows x 16 columns]

# %% [markdown]
# ### Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
#80-20 split
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#      pclass     sex        age  sibsp  parch      fare embarked   class  who  \
# 331       1    male  45.500000      0      0   28.5000        S   First    1
# 733       2    male  23.000000      0      0   13.0000        S  Second    1
# 382       3    male  32.000000      0      0    7.9250        S   Third    1
# 704       3    male  26.000000      1      0    7.8542        S   Third    1
# 813       3  female   6.000000      4      2   31.2750        S   Third    0
# ..      ...     ...        ...    ...    ...       ...      ...     ...  ...
# 106       3  female  21.000000      0      0    7.6500        S   Third    2
# 270       1    male  29.699118      0      0   31.0000        S   First    1
# 860       3    male  41.000000      2      0   14.1083        S   Third    1
# 435       1  female  14.000000      1      2  120.0000        S   First    0
# 102       1    male  21.000000      0      1   77.2875        S   First    1
#
#      adult_male  deck  embark_town alive  alone
# 331        True     C  Southampton    no   True
# 733        True  None  Southampton    no   True
# 382        True  None  Southampton    no   True
# 704        True  None  Southampton    no  False
# 813       False  None  Southampton    no  False
# ..          ...   ...          ...   ...    ...
# 106       False  None  Southampton   yes   True
# 270        True  None  Southampton    no   True
# 860        True  None  Southampton    no  False
# 435       False     B  Southampton   yes  False
# 102        True     D  Southampton    no  False
#
# [712 rows x 14 columns]

# %%
y_train
# Out:
# 331    0
# 733    0
# 382    0
# 704    0
# 813    0
#       ..
# 106    1
# 270    0
# 860    0
# 435    1
# 102    0
# Name: survived, Length: 712, dtype: int64
